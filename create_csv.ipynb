# %%
romajiTable = [['a', 'あ', 'ア'], ['i', 'い', 'イ'], ['u', 'う', 'ウ'], ['e', 'え', 'エ'], ['o', 'お', 'オ'], ['ka', 'か', 'カ'], ['ki', 'き', 'キ'], ['ku', 'く', 'ク'], ['ke', 'け', 'ケ'], ['ko', 'こ', 'コ'], ['sa', 'さ', 'サ'], ['shi', 'し', 'シ'], ['su', 'す', 'ス'], ['se', 'せ', 'セ'], ['so', 'そ', 'ソ'], ['ta', 'た', 'タ'], ['chi', 'ち', 'チ'], ['tsu', 'つ', 'ツ'], ['te', 'て', 'テ'], ['to', 'と', 'ト'], ['na', 'な', 'ナ'], ['ni', 'に', 'ニ'], ['nu', 'ぬ', 'ヌ'], ['ne', 'ね', 'ネ'], ['no', 'の', 'ノ'], ['ha', 'は', 'ハ'], ['hi', 'ひ', 'ヒ'], ['fu', 'ふ', 'フ'], ['he', 'へ', 'ヘ'], ['ho', 'ほ', 'ホ'], ['ma', 'ま', 'マ'], ['mi', 'み', 'ミ'], ['mu', 'む', 'ム'], ['me', 'め', 'メ'], ['mo', 'も', 'モ'], ['ya', 'や', 'ヤ'], ['yu', 'ゆ', 'ユ'], ['yo', 'よ', 'ヨ'], ['ra', 'ら', 'ラ'], ['ri', 'り', 'リ'], ['ru', 'る', 'ル'], ['re', 'れ', 'レ'], ['ro', 'ろ', 'ロ'], ['wa', 'わ', 'ワ'], ['wo', 'を', 'ヲ'], ['n', 'ん', 'ン'], ['ga', 'が', 'ガ'], ['gi', 'ぎ', 'ギ'], ['gu', 'ぐ', 'グ'], ['ge', 'げ', 'ゲ'], ['go', 'ご', 'ゴ'], ['za', 'ざ', 'ザ'], ['ji', 'じ', 'ジ'], ['zu', 'ず', 'ズ'], ['ze', 'ぜ', 'ゼ'], ['zo', 'ぞ', 'ゾ'], ['da', 'だ', 'ダ'], ['di', 'ぢ', 'ヂ'], ['du', 'づ', 'ヅ'], ['de', 'で', 'デ'], ['do', 'ど', 'ド'], ['ba', 'ば', 'バ'], ['bi', 'び', 'ビ'], ['bu', 'ぶ', 'ブ'], ['be', 'べ', 'ベ'], ['bo', 'ぼ', 'ボ'], ['pa', 'ぱ', 'パ'], ['pi', 'ぴ', 'ピ'], ['pu', 'ぷ', 'プ'], ['pe', 'ぺ', 'ペ'], ['po', 'ぽ', 'ポ']]

r = set()
for j in romajiTable:
  r.update(j[1])

print(r)
# Out:
# {'か', 'ぼ', 'つ', 'じ', 'ん', 'び', 'せ', 'り', 'が', 'め', 'と', 'ぷ', 'よ', 'こ', 'ず', 'た', 'い', 'う', 'ぞ', 'だ', 'ふ', 'わ', 'で', 'る', 'ぺ', 'に', 'ろ', 'な', 'ぢ', 'へ', 'ざ', 'ぽ', 'げ', 'ぴ', 'あ', 'ぐ', 'み', 'づ', 'ぜ', 'ぬ', 'ね', 'し', 'え', 'ぶ', 'は', 'さ', 'ら', 'べ', 'も', 'す', 'の', 'れ', 'ひ', 'ほ', 'そ', 'ば', 'ま', 'き', 'む', 'ぎ', 'ご', 'を', 'て', 'ゆ', 'ぱ', 'ど', 'け', 'お', 'ち', 'や', 'く'}

# %%
temp = []

f = open("/content/kanji and meaning.txt", "r")
for i, x in enumerate(f):
  t = x
  x = x.split(" ")
  try:
    if x[1][1] in r:
      kanji = x[0]
      hiragana = x[1]
      hiragana = hiragana.replace("\n", "").replace("(", "").replace(")", "")
      temp.append([x[0], hiragana])
    else:
      temp[len(temp) - 1].append(t)
  except:
    if i > 1:
      temp[len(temp) - 1].append(t)
    w = 1

f.close()

# %%
temp
# Out:
# [['日',
#   'ひ',
#   'day; days; sun; sunshine; sunlight; case (esp. unfortunate); event\n'],
#  ['一',
#   'いち',
#   'one; best; first; foremost; beginning; start; bottom string (on a shamisen, etc.)\n'],
#  ['大', 'おお', 'big; large\n'],
#  ['十', 'じゅう、とお、と', 'ten\n'],
#  ['二', 'に、ふた、ふ、ふう', 'two\n'],
#  ['本',
#   'ほん',
#   'book; volume; script; this; present; main; head; real; regular; counter for long cylindrical things; counter for films, TV shows, etc.; counter for goals, home runs, etc.; counter for telephone calls\n'],
#  ['三', 'さん、み', 'three; tri-\n'],
#  ['同', 'どう', 'the same; the said; ibid.\n'],
#  ['政', 'まつりごと、せい', 'rule; government\n'],
#  ['自',
#   'じ、ころ',
#   'self-; from ...; this ... (in contrast to some other ...); aforementioned\n'],
#  ['見る',
#   'みる',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(temp, columns=["kanji", "kana", "meaning", "?", "??"])

# %%
df[df['?'].notnull()]
# Out:
#      kanji   kana  ...            ?                           ??
# 308      劇     げき  ...  河 (ホー、かわ)\n  discarded tiles; discards\n
# 452      跡     あと  ...     包 (パオ)\n                       yurt\n
# 1193     鮫  さめ、サメ  ...     牌 (パイ)\n                       tile\n
#
# [3 rows x 5 columns]

# %%
print(df.loc[0]["?"])
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
print(type(df.loc[0]["kanji"]))
# Out:
# <class 'str'>

# %%
df = df[["kanji", "kana", "meaning"]]

# %%
df['meaning'] = df['meaning'].str.replace("\n", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      kanji       kana                                            meaning
# 0        日          ひ  day; days; sun; sunshine; sunlight; case (esp....
# 1        一         いち  one; best; first; foremost; beginning; start; ...
# 2        大         おお                                         big; large
# 3        十   じゅう、とお、と                                                ten
# 4        二  に、ふた、ふ、ふう                                                two
# ...    ...        ...                                                ...
# 1302     繭         まゆ                                             cocoon
# 1303     釘         くぎ                      nail (i.e. small metal spike)
# 1304     狸    たぬき、タヌキ  tanuki (Nyctereutes procyonoides); raccoon dog...
# 1305     壬    じん、みずのえ    9th in rank; ninth sign of the Chinese calendar
# 1306     硯        すずり                                           inkstone
#
# [1307 rows x 3 columns]

# %%
df.to_csv('kanji_kana_meaning.csv', header=False, index=False)
