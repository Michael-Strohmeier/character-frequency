# %%
f = open("/content/basic_words.txt", "r")

# ['い', 'う', 'か', 'る', 'ん', 'く', 'し', 'き', 'と', 'た', 'こ']

d = dict()
temp = []
for x in f:
  d[x.split("、")[0]] = x

# %%
ordered = [['い', 0.058666666666666666],
 ['う', 0.051666666666666666],
 ['か', 0.047],
 ['る', 0.044],
 ['ん', 0.043],
 ['く', 0.04],
 ['し', 0.03766666666666667],
 ['き', 0.03266666666666666],
 ['と', 0.029333333333333333],
 ['た', 0.028],
 ['こ', 0.027333333333333334],
 ['つ', 0.027],
 ['さ', 0.024],
 ['お', 0.023666666666666666],
 ['ま', 0.023666666666666666],
 ['り', 0.023666666666666666],
 ['は', 0.019666666666666666],
 ['み', 0.019333333333333334],
 ['ら', 0.017333333333333333],
 ['あ', 0.017],
 ['ょ', 0.016666666666666666],
 ['な', 0.016666666666666666],
 ['ち', 0.016],
 ['も', 0.015],
 ['じ', 0.013333333333333334],
 ['わ', 0.013333333333333334],
 ['け', 0.012],
 ['す', 0.012],
 ['ひ', 0.011666666666666667],
 ['め', 0.011],
 ['え', 0.011],
 ['や', 0.011],
 ['に', 0.009666666666666667],
 ['ゅ', 0.009333333333333334],
 ['ど', 0.009333333333333334],
 ['の', 0.009333333333333334],
 ['せ', 0.008666666666666666],
 ['ろ', 0.008333333333333333],
 ['そ', 0.008333333333333333],
 ['だ', 0.008],
 ['ふ', 0.007666666666666666],
 ['ぎ', 0.007333333333333333],
 ['よ', 0.007333333333333333],
 ['む', 0.007333333333333333],
 ['ね', 0.007333333333333333],
 ['ご', 0.007],
 ['ず', 0.007],
 ['ば', 0.007],
 ['ほ', 0.006333333333333333],
 ['れ', 0.006333333333333333],
 ['が', 0.006333333333333333],
 ['び', 0.006333333333333333],
 ['ゆ', 0.006333333333333333],
 ['て', 0.006],
 ['ぼ', 0.005333333333333333],
 ['げ', 0.004666666666666667],
 ['ぶ', 0.004666666666666667],
 ['ゃ', 0.0036666666666666666],
 ['ぜ', 0.003],
 ['ぞ', 0.003],
 ['ざ', 0.002],
 ['へ', 0.002],
 ['ぐ', 0.002],
 ['べ', 0.002],
 ['っ', 0.0016666666666666668],
 ['ぬ', 0.0016666666666666668],
 ['で', 0.0016666666666666668],
 ['づ', 0.0013333333333333333],
 ['ぱ', 0.0003333333333333333]]

# %%
ordered = [o[0] for o in ordered]
print(ordered)
# Out:
# ['い', 'う', 'か', 'る', 'ん', 'く', 'し', 'き', 'と', 'た', 'こ', 'つ', 'さ', 'お', 'ま', 'り', 'は', 'み', 'ら', 'あ', 'ょ', 'な', 'ち', 'も', 'じ', 'わ', 'け', 'す', 'ひ', 'め', 'え', 'や', 'に', 'ゅ', 'ど', 'の', 'せ', 'ろ', 'そ', 'だ', 'ふ', 'ぎ', 'よ', 'む', 'ね', 'ご', 'ず', 'ば', 'ほ', 'れ', 'が', 'び', 'ゆ', 'て', 'ぼ', 'げ', 'ぶ', 'ゃ', 'ぜ', 'ぞ', 'ざ', 'へ', 'ぐ', 'べ', 'っ', 'ぬ', 'で', 'づ', 'ぱ']

# %%
temp = []

char_list = ['い', 'う', 'か', 'る', 'ん']

char_list = char_list[0:2]
for key in d.keys():
  matched_list = [characters in char_list for characters in key]
  if all(matched_list):
    temp.append(key)

temp
# Out:
# ['いい', 'いう']

# %%
temp = getWords(2)
temp

# %%
def ok(n, char_list):
  temp = []

  char_list = char_list[0:n]
  for key in d.keys():
    matched_list = [characters in char_list for characters in key]
    if all(matched_list):
      temp.append(key)
  
  return temp

def okok(n, t, char_list):
  p = []
  for o in t:
    if char_list[n-1] in o:
      p.append(o)

  return p

# %%
freqList = ['い', 'う', 'か', 'る', 'き', 'ん', 'く', 'し', 'と', 'た', 'こ', 'つ', 'さ', 'お', 'ま', 'り', 'は', 'み', 'ら', 'あ', 'ょ', 'な', 'ち', 'も', 'じ', 'わ', 'け', 'す', 'ひ', 'め', 'え', 'や', 'に', 'ゅ', 'ど', 'の', 'せ', 'ろ', 'そ', 'だ', 'ふ', 'ぎ', 'よ', 'む', 'ね', 'ご', 'ず', 'ば', 'ほ', 'れ', 'が', 'び', 'ゆ', 'て', 'ぼ', 'げ', 'ぶ', 'ゃ', 'ぜ', 'ぞ', 'ざ', 'へ', 'ぐ', 'べ', 'っ', 'ぬ', 'で', 'づ', 'ぱ']

n = 1
r = ok(n, ordered)
q = okok(n, r, ordered)
print(q)
# Out:
# ['いい']

# %%
n = 2          # don't forget to add "ki", "き" to the char_list/frequency list
r = ok(n, ordered)      # in here make n instead be the number of characters seen
q = okok(n, r, ordered) # change it to take in the character of the flashcard you are on
print(q)
# Out:
# ['いう']

# %%
for i in range(len(ordered)):
  n = i
  r = ok(n, ordered)
  q = okok(n, r, ordered)
  print(ordered[n])
  print(q)
# Out:
# い
# []
# う
# ['いい']
# か
# ['いう']
# る
# ['かい', 'かう']
# ん
# ['かるい', 'いる', 'うる']
# く
# []
# し
# ['いく', 'くる', 'かく']
# き
# ['しかい', 'うし', 'しか', 'しし', 'しかる', 'しる']
# と
# ['き', 'くき', 'きく', 'くうき', 'きん', 'いきる', 'きる']
# た
# ['かかと', 'とき', 'とし', 'と', 'とる']
# こ
# ['かた', 'たか', 'たい', 'きた', 'した', 'たいいく', 'たかい', 'かたい', 'いたい', 'うたう', 'かたる']
# つ
# ['こし', 'いとこ', 'くうこう', 'かこ']
# さ
# ['つき', 'くつ', 'くつした', 'いつつ', 'うつくしい', 'うつ', 'たつ', 'つかう', 'つくる']
# お
# ['さる', 'くさ', 'さとう', 'さつ', 'かさ', 'さん', 'くさい']
# ま
# ['おとこ', 'かお', 'おとうと', 'おい', 'かつお', 'しお', 'とおい', 'おく', 'とお', 'おおきい', 'おいしい', 'おこる', 'おる']
# り
# ['つま', 'しまい', 'うま', 'さんま', 'くま', 'まつ', 'くるま', 'まん', 'いま', 'うまい', 'かたまる', 'うまる']
# は
# ['しり', 'とり', 'こおり', 'とおり', 'りか']
# み
# ['は', 'はは', 'はしる', 'はく']
# ら
# ['かみ', 'みみ', 'み', 'たたみ', 'はさみ', 'さみしい', 'みる']
# あ
# ['とら', 'さくら', 'いらい', 'みらい', 'からい', 'つらい', 'はたらく']
# ょ
# ['あたし', 'あし', 'あたま', 'あした', 'あさ', 'あらし', 'あか', 'あお', 'あたらしい', 'あつい', 'あまい', 'あるく', 'あく', 'あきる', 'あう', 'あつまる']
# な
# ['きょうし', 'りょうしん', 'りょうり', 'きょう']
# ち
# ['おんな', 'はな', 'おなか', 'さかな', 'かみなり', 'みなみ', 'なまり', 'なな', 'ななつ', 'かなしい', 'なく']
# も
# ['くち', 'ち', 'ちち', 'ちょう', 'ちょうしょく', 'ちかい', 'つち', 'ちょうこく', 'みち', 'ちり', 'いち', 'はち', 'こちら', 'あちら', 'ちいさい']
# じ
# ['もも', 'きも', 'いもうと', 'いも', 'くもり', 'おもい', 'もつ']
# わ
# ['じんるい', 'しょうじょ', 'おじ', 'あじ', 'じかん', 'こうじょう', 'もじ', 'じ', 'かんじ', 'じしょ', 'はじまる']
# け
# ['わたし', 'わたくし', 'わし', 'いわし', 'なわ', 'わるい', 'わかい', 'こわい', 'さわる', 'かわく', 'おわる', 'わらう']
# す
# ['けいさつかん', 'けんちくか', 'ける', 'あける']
# ひ
# ['からす', 'いす', 'すうじ', 'さんすう', 'さす', 'すわる', 'ます', 'はなす', 'なおす']
# め
# ['ひと', 'ひじ', 'ひつじ', 'ひ', 'ひる', 'ひも', 'ひこうき', 'ひとつ', 'ひみつ', 'ひくい']
# え
# ['め', 'つめ', 'めい', 'うめ', 'こめ', 'まめ', 'あめ', 'ななめ', 'つめたい', 'さめる', 'きめる', 'しめる']
# や
# ['かえる', 'うえ', 'まえ', 'つくえ', 'いえ', 'えり', 'えき', 'え', 'つかえる', 'ひえる', 'える']
# に
# ['やさい', 'おやつ', 'たこやき', 'やくしょ', 'やすい', 'やさしい', 'やわらかい']
# ゅ
# ['きんにく', 'にく', 'あに', 'にわとり', 'にんじん', 'にし', 'に']
# ど
# ['かしゅ', 'りゅう', 'しゅう', 'きゅう', 'じゅう']
# の
# ['こども', 'どう', 'まど', 'みどり', 'どちら', 'じどう', 'おどる']
# せ
# ['おとこのひと', 'おとこのこ', 'おんなのひと', 'おんなのこ', 'わかもの', 'いきもの', 'きのこ', 'のみもの', 'きのう', 'きもの', 'ここのつ', 'たのしい']
# ろ
# ['せいじか', 'せんせい', 'せなか', 'せみ', 'みせ', 'つりせん', 'せん', 'せいしき']
# そ
# ['こころ', 'うしろ', 'どろ', 'どうろ', 'いろ', 'きいろ', 'しろ', 'くろ', 'はいいろ', 'ろく', 'おどろく']
# だ
# ['みそ', 'そら', 'そちら', 'そなわる']
# ふ
# ['はだ', 'きょうだい', 'くだもの', 'だいこん', 'ひだり', 'みだす']
# ぎ
# ['ひふ', 'そふ', 'ふん', 'たいふう', 'ふとん', 'ふくろ', 'ふうとう', 'ふく', 'わふく', 'ふたつ', 'ふとい', 'ふるい', 'ふえる', 'ふとる']
# よ
# ['うさぎ', 'ぎゅうにゅう', 'みぎ', 'ぎん', 'かいぎ', 'くぎ', 'かぎ', 'じょうぎ']
# む
# ['こよみ', 'よる', 'たいよう', 'ようふく', 'ひつよう', 'よん', 'ないよう']
# ね
# ['むし', 'むぎ', 'むこう', 'けむり', 'むらさき', 'さむい', 'うむ', 'かむ', 'のむ', 'こむ', 'むく', 'よむ', 'かなしむ', 'やすむ']
# ご
# ['しょうねん', 'すね', 'むね', 'あね', 'ねこ', 'ね', 'いね', 'かね', 'まんねんひつ', 'ねる']
# ず
# ['かんごし', 'かんごふ', 'まご', 'ひるごはん', 'ごはん', 'えいご', 'ちゅうごくご', 'どいつご', 'ふらんすご', 'ご', 'すごい', 'うごく']
# ば
# ['ねずみ', 'すずめ', 'みず', 'むずかしい', 'まずい']
# ほ
# ['おば', 'ばけもの', 'さば', 'ばんごはん', 'ばん', 'じどうはんばいき', 'かばん', 'はば', 'すばらしい']
# れ
# ['ほね', 'ほし', 'にほんご', 'ほん', 'じょうほう', 'ほそい', 'ほめる']
# が
# ['おれ', 'はれ', 'れきし', 'れい', 'うれしい', 'あらわれる', 'こわれる', 'みだれる', 'たおれる', 'うもれる', 'はずれる', 'つかれる', 'わかれる']
# び
# ['がま', 'かいがら', 'ひがし', 'めがね', 'ひらがな', 'がいこくご', 'おんがく', 'にがい']
# ゆ
# ['くちびる', 'くび', 'びょうき', 'えび', 'びょう', 'ようび', 'にちようび', 'かようび', 'すいようび', 'もくようび', 'きんようび', 'どようび', 'とびら', 'さびしい', 'よろこび']
# て
# ['ゆび', 'しょうゆ', 'ゆうがた', 'ゆき', 'ゆ', 'かゆい']
# ぼ
# ['て', 'てくび', 'てのひら', 'てんき', 'てまえ', 'てつ', 'てつどう', 'てがみ', 'すてる']
# げ
# ['ぼく', 'しょうぼうし', 'そぼ']
# ぶ
# ['にんげん', 'ひげ', 'げり', 'げつようび', 'ゆげ', 'げんかん', 'なげる']
# ゃ
# ['どうぶつ', 'ぶた', 'しょくぶつ', 'しんぶん', 'とぶ', 'よろこぶ', 'あそぶ']
# ぜ
# ['あかちゃん', 'いしゃ', 'ちゃ', 'おちゃ', 'しゃかい', 'かいしゃ', 'じてんしゃ', 'ちゃいろ', 'ひゃく']
# ぞ
# ['かぜ', 'こぜに']
# ざ
# ['かんぞう', 'しんぞう', 'かぞく', 'ぞう', 'きんぞく']
# へ
# ['ひざ', 'けいざい', 'げんざい']
# ぐ
# ['へいし', 'へび', 'へる']
# べ
# ['まぐろ', 'ぶんぼうぐ', 'およぐ', 'なぐる', 'すぐれる', 'かぐ', 'なぐさめる']
# っ
# ['べんごし', 'たべもの', 'べんきょう', 'たべる']
# ぬ
# ['おっと', 'がっこう', 'きって', 'にっき', 'みっつ', 'よっつ', 'むっつ', 'やっつ', 'けっこん']
# で
# ['いぬ', 'しぬ']
# づ
# ['うで', 'でんき', 'ふで', 'そで', 'でんしゃ', 'でかける']
# ぱ
# []

# %%
n = 4
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 5
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 6
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 7
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 8
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 9
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 10
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 11
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 12
r = ok(n)
q = okok(n, r)
print(q)

# %%
n = 13
r = ok(n)
q = okok(n, r)
print(q)
